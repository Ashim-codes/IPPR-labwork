# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashim-codes/IPPR-labwork/blob/main/lab3/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Basics: Variables, Data Types, Type Conversion and String Manipulation

# %%
#this is a single line comment
"""this is a multi comment
also called a docstring"""
print("DATA TYPE AND VARIABLES")
#numbers
age = 21 #integer
price = 19.99 #float
complex_number = 2 + 3j #complex number

#text
name = "Ashim" #string
greeting = 'Namaste , Konnichiwa'

#boolean
is_student = True #boolean

has_job = False #boolean

#display variable and their types
print(f"Name: {name}, Type: {type(name)}")
print(f"Age: {age}, Type: {type(age)}")
print(f"Price: {price}, Type: {type(price)})")
print(f"Is Student: {is_student}, Type: {type(is_student)}")


# 3. type conversion

print("\n" + "="*50)
print("TYPE CONVERSION")
print("="*50)

#string to Integer
num_str="100"
num_int=int(num_str)
print(f'converting"{num_str}" to integer : {num_int}')

#integer to float
num_float = float(age)
print(f"Converting{age} to float :{num_float}")

#number to string
pi = 3.14159
pi_str = str(pi)
print(f"converting {pi} to string : {pi_str}")

# 4. string operations

print("\n"+"="*50)
print("STRING OPERATIONS")
print("="*50)

greeting = " Konnichiwa"
name = "Ashu"

#string concatenation
combined = greeting + " " + name
print(f"concatenation:{combined}")

#string repetition
laugh = "HE" * 10
print(f"repetition : {laugh}")

# string methods
text = " Programming in python "
print(f"Original text: '{text}'")
print(f"strip whitespace: '{text.strip()}'")
print(f"Lowercase: '{text.lower()}'")
print(f"Uppercase: '{text.upper()}'")
print(f"Replace python with java: '{text.replace('Python', 'Java')}'")
print(f"Split into words: {text.split()}")


# string formatting(f-strings)
print("\n STRING FORMATTING (f-strings)")
name = "Charlie"
score = 95.5
print(f"student: {name}, scored {score}")

# string slicing
print("\n STRING SLICING")
word = "Programming"
print(f"Word: {word}")
print(f" First 3 characters: {word[:3]}")
print(f" Last 3 characters: {word[-3:]}")
print(f" Reversed: {word[::-1]}")
# Out:
# DATA TYPE AND VARIABLES
# Name: Ashim, Type: <class 'str'>
# Age: 21, Type: <class 'int'>
# Price: 19.99, Type: <class 'float'>)
# Is Student: True, Type: <class 'bool'>
#
# ...
# TYPE CONVERSION
# ...
# converting"100" to integer : 100
# Converting21 to float :21.0
# converting 3.14159 to string : 3.14159
#
# ...
# STRING OPERATIONS
# ...
# concatenation: Konnichiwa Ashu
# repetition : HEHEHEHEHEHEHEHEHEHE
# Original text: ' Programming in python '
# strip whitespace: 'Programming in python'
# Lowercase: ' programming in python '
# Uppercase: ' PROGRAMMING IN PYTHON '
# Replace python with java: ' Programming in python '
# Split into words: ['Programming', 'in', 'python']
#
#  STRING FORMATTING (f-strings)
# student: Charlie, scored 95.5
#
#  STRING SLICING
# Word: Programming
#  First 3 characters: Pro
#  Last 3 characters: ing
#  Reversed: gnimmargorP

# %%
# Basic operations
print("*" * 30)
print("\nBASIC OPERATIONS")
print("*" * 30)

a = 10
b = 3

# Arithmetic operations
print("-" * 30)
print("\nARITHMETIC OPERATIONS")
print("-" * 30)
print(f"a: {a}, b: {b}")
print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
print(f"Modulus: {a} % {b} = {a % b}")
print(f"Exponentiation: {a} ** {b} = {a ** b}")

# Comparison operations
print("-" * 30)
print("\nCOMPARISON OPERATIONS")
print("-" * 30)
print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
print(f"{a} >= {b}: {a >= b}")
print(f"{a} <= {b}: {a <= b}")
# Out:
# ******************************
#
# BASIC OPERATIONS
# ******************************
# ------------------------------
#
# ARITHMETIC OPERATIONS
# ------------------------------
# a: 10, b: 3
# Addition: 10 + 3 = 13
# Subtraction: 10 - 3 = 7
# Multiplication: 10 * 3 = 30
# Division: 10 / 3 = 3.3333333333333335
# Modulus: 10 % 3 = 1
# Exponentiation: 10 ** 3 = 1000
# ------------------------------
#
# COMPARISON OPERATIONS
# ------------------------------
# 10 == 3: False
# 10 != 3: True
# 10 > 3: True
# 10 < 3: False
# 10 >= 3: True
# 10 <= 3: False

# %%
# Logical operations
print("-" *30)
print("\n LOGICAL OPERATIONS")
print("-" *30)
x = True
y = False
$0
print(f"x: {x}, y: {y}")
print(f"x and y: {x and y}")
print(f"x or y: {x or y}")
print(f"not x: {not x}")

# Getting user input
print("-" *30)
print("\n GETTING USER INPUT")
print("-" *30)
user_name = input("Enter your name: ")
user_age = input("Enter your age:")
print(f"Hello, {user_name}!")
print(f"{user_name} is {user_age} years old.")
# Out:
# ------------------------------
#
#  LOGICAL OPERATIONS
# ------------------------------
# x: True, y: False
# x and y: False
# x or y: True
# not x: False
# ------------------------------
#
#  GETTING USER INPUT
# ------------------------------
# Enter your name: Ashim Shrestha
# Enter your age:21
# Hello, Ashim Shrestha!
# Ashim Shrestha is 21 years old.
